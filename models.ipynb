# %% [markdown]
# # Models

# %% [markdown]
# ## Cluster setup and initialization

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster()
client = Client(cluster)
client
# Out:
# 2023-03-14 18:23:05,002 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-y8ggn4kw', purging
# 2023-03-14 18:23:05,617 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ymk8rk8r', purging
# /usr/lib64/python3.10/contextlib.py:142: UserWarning: Creating scratch directories is taking a surprisingly long time. (1.06s) This is often due to running workers on a network file system. Consider specifying a local-directory to point workers to write scratch data to a local disk.
#   next(self.gen)
# <Client: 'tcp://127.0.0.1:36629' processes=4 threads=8, memory=15.46 GiB>

# %% [markdown]
# ## Data import and treatment

# %%
# Import the data
import dask.dataframe as dd
ddf = dd.read_parquet('data/c1.parquet')

# %%
labels_c1 = ddf.type.value_counts().compute()
# Out:
# political     292180
# unreliable    172478
# bias          147189
# conspiracy    124418
# fake          123966
# rumor          69018
# unknown        47600
#                45988
# hate           41404
# junksci        23048
# clickbait      21761
# satire         14326
# reliable        6624
# Name: type, dtype: int64

# %%
ddfc9 = dd.read_parquet('data/c9.parquet')

# %%
labels_c9 = ddf2.type.value_counts().compute()

# %% [markdown]
# ## Simple model - SBERT
